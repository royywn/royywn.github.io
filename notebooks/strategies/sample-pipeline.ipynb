# %% [raw]
# ---
# title: "Sample: the notebook publishing pipeline"
# description: "A draft-only sample proving the ipynb-to-markdown pipeline end to end. Not research."
# category: "infra"
# tags: ["meta", "pipeline"]
# status: "idea"
# date: 2026-06-12
# draft: true
# ---

# %% [markdown]
# This notebook exists to verify the publishing pipeline: a raw frontmatter cell, a hidden setup cell, and one plot output that must survive the ipynb-to-markdown conversion with its image intact. It is marked `draft: true` and never ships to production.

# %%
# HIDE
# setup cells tagged like this are stripped at publish time
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 4 * np.pi, 200)
fig, ax = plt.subplots(figsize=(6, 3))
ax.plot(x, np.sin(x))
ax.set_title("sample figure rendered by the conversion pipeline")
fig.tight_layout()
fig
